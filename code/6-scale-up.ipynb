# %%
# YaRN, GQA, SwiGLU, sliding ring-buffer KV cache, QK RMSnorm

# %% [markdown]
# adding multiple layers, activation recomputation, Gradient accumulation, data parallelism, ZeRO 1/2/3, tensor parallelism, pipeline parallelism
