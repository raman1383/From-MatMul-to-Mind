# %%
# imports, file paths, MODEL_CONFIGS, cuda

import os
import sys
import math
import torch
import random
import numpy as np
import torch.nn as nn
from pathlib import Path
import torch.nn.functional as F
import matplotlib.pyplot as plt
from einops import rearrange, reduce, repeat, einsum


import training_runtime 
import inference_runtime
from rms_norm import RMSNorm


MODEL_CONFIGS = {
    "embed_dim"   : 2**5,   # 32
    "max_seq_len" : 2**6,   # 64
    "batch_size"  : 2**4,   # 16
    "vocab_size"  : 2**11,  # 2048
    "learning_rate" : 1e-3,
    "save_path" : "../models/level5.2_mixture_of_experts.pt",
    "loss_history" : "../models/level5.2_feed_forward_mlp_loss_history.txt",

    "num_attn_heads": 2**2,  # 4
    "num_mlp_experts": 2**3,  # 8
}



# Device configuration
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)
