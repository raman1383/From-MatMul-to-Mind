# %%
# simulate the topology, B/W, jitter, arithmetic Intensity, where bounded by what(comp/mem/comm)

# %%
# comp_node:

# select your abstraction layer from a single SM to an H100

# %%
# comms_edge

# HBM->SMEM, SMEM->reg, NVlink,

# %%
# generate graphical summary, see what travels where, catch inefficiencies
