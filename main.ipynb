# %%
import math

math.log2(1000)
# Out:
# 9.965784284662087

# %%
# plot functions
import matplotlib.pyplot as plt

# plot log 2
x = [i for i in range(1, 10001)]
y = [math.log2(i) for i in x]
plt.plot(x, y)
